# %%
import hachiChart

data_name = ["1500走","50走","シャトルラン"]
f1 = [-0.94,-0.27,-0.94]
f2 = [0.12,-0.98,0.12]

hachiChart.HachiChart(xlabel="第1因子負荷量", ylabel="第2因子負荷量", label=data_name, f1=f1, f2=f2).show()
